# %%
from box import ConfigBox

# %%
from cnnClassifier.constants import CONFIG_FILE_PATH, PARAMS_FILE_PATH
import os

print(CONFIG_FILE_PATH, os.path.exists(CONFIG_FILE_PATH))
print(PARAMS_FILE_PATH, os.path.exists(PARAMS_FILE_PATH))
# Out:
# C:\Users\Krishna Nandi\Documents\Symbiosis Projects\Chicken_Disease_Classification\config\config.yaml True
# C:\Users\Krishna Nandi\Documents\Symbiosis Projects\Chicken_Disease_Classification\params.yaml True

# %%
from cnnClassifier.entity.config_entity import TrainingConfig
import inspect

print(inspect.getsource(TrainingConfig))
# Out:
# @dataclass(frozen=True)
# class TrainingConfig:
#     root_dir: Path
#     trained_model_path: Path
#     updated_base_model_path: Path
#     training_data: Path
#     params_epochs: int
#     params_batch_size: int
#     params_is_augmentation: bool
#     params_image_size: list
#     params_learning_rate: float

# %%
from cnnClassifier.config.configuration import ConfigurationManager
config = ConfigurationManager()
training_config = config.get_training_config()

print(training_config)
# Out:
# [2026-02-04 15:01:22,900: INFO: common: yaml file: C:\Users\Krishna Nandi\Documents\Symbiosis Projects\Chicken_Disease_Classification\config\config.yaml loaded successfully]
# [2026-02-04 15:01:22,914: INFO: common: yaml file: C:\Users\Krishna Nandi\Documents\Symbiosis Projects\Chicken_Disease_Classification\params.yaml loaded successfully]
# [2026-02-04 15:01:22,930: INFO: common: created directory at: artifacts]
# [2026-02-04 15:01:22,933: INFO: common: created directory at: artifacts\training]
# TrainingConfig(root_dir=WindowsPath('artifacts/training'), trained_model_path=WindowsPath('artifacts/training/model.h5'), updated_base_model_path=WindowsPath('artifacts/prepare_base_model/base_model_updated.h5'), training_data=WindowsPath('artifacts/data_ingestion/Chicken-fecal-images'), params_epochs=1, params_batch_size=16, params_is_augmentation=True, params_image_size=BoxList([224, 224, 3]), params_learning_rate=0.01)

# %%
import sys
print(sys.executable)
# Out:
# c:\ancond\envs\chicken310\python.exe

# %%
from cnnClassifier.entity.config_entity import TrainingConfig
import inspect
print(inspect.getsource(TrainingConfig))
# Out:
# @dataclass(frozen=True)
# class TrainingConfig:
#     root_dir: Path
#     trained_model_path: Path
#     updated_base_model_path: Path
#     training_data: Path
#     params_epochs: int
#     params_batch_size: int
#     params_is_augmentation: bool
#     params_image_size: list
#     params_learning_rate: float

# %%
from pathlib import Path

path = Path("artifacts/prepare_base_model/base_model_updated.h5")
print(path.exists())
# Out:
# False

# %%
from pathlib import Path

ROOT_DIR = Path.cwd().parent   # goes from research → project root
path = ROOT_DIR / "artifacts" / "prepare_base_model" / "base_model_updated.h5"

print(path)
print(path.exists())
# Out:
# c:\Users\Krishna Nandi\Documents\Symbiosis Projects\Chicken_Disease_Classification\artifacts\prepare_base_model\base_model_updated.h5
# True

# %%
from cnnClassifier.config.configuration import ConfigurationManager

config = ConfigurationManager()
training_config = config.get_training_config()

print(training_config.updated_base_model_path)
print(training_config.updated_base_model_path.exists())
# Out:
# [2026-02-04 15:01:23,086: INFO: common: yaml file: C:\Users\Krishna Nandi\Documents\Symbiosis Projects\Chicken_Disease_Classification\config\config.yaml loaded successfully]
# [2026-02-04 15:01:23,096: INFO: common: yaml file: C:\Users\Krishna Nandi\Documents\Symbiosis Projects\Chicken_Disease_Classification\params.yaml loaded successfully]
# [2026-02-04 15:01:23,099: INFO: common: created directory at: artifacts]
# [2026-02-04 15:01:23,103: INFO: common: created directory at: artifacts\training]
# artifacts\prepare_base_model\base_model_updated.h5
# False
