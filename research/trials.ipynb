# %%
from box import ConfigBox

# %%
from cnnClassifier.constants import CONFIG_FILE_PATH, PARAMS_FILE_PATH
import os

print(CONFIG_FILE_PATH, os.path.exists(CONFIG_FILE_PATH))
print(PARAMS_FILE_PATH, os.path.exists(PARAMS_FILE_PATH))
# Out:
# C:\Users\Krishna Nandi\Documents\Symbiosis Projects\Chicken_Disease_Classification\config\config.yaml True
# C:\Users\Krishna Nandi\Documents\Symbiosis Projects\Chicken_Disease_Classification\params.yaml True
